# %%
import requests
from bs4 import BeautifulSoup

# %%
# URL of the website we want to scrape
url = "https://status.snowflake.com/"

# Make a GET request to the website
response = requests.get(url)

# Parse the HTML content of the website with BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Find the table containing the Azure - East US 2 (Virginia) details
#table = soup.find("table", {"class": "table-service-status"})
#rows = table.find_all("tr")
# for row in rows:
#     if "Azure - East US 2 (Virginia)" in row.text:
#         status = row.find("td", {"class": "col-service-status"}).text.strip()
#         break

# # Print the status
# print("Azure - East US 2 (Virginia) status:", status)

# %%
region_div = soup.find("div", {"class": "component-inner-container status-green ", "data-component-id": "4pbr6y23kkht"})

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- force IE browsers in compatibility mode to use their most aggressive rendering engine -->
#   <meta charset="utf-8"/>
#   <title>
#    Snowflake Status
#   </title>
#   <meta content="Welcome to Snowflake's home for real-time and historical data on system performance." name="description"/>
#   <!-- Mobile viewport optimization -->
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <!-- Time this page was rendered - http://purl.org/dc/terms/issued -->
#   <meta content="1678595223" name="issued"/>
#   <!-- Mobile IE allows us to activate ClearType technology for smoothing fonts for easy reading -->
#   <meta content="on" http-equiv="cleartype"/>
#   <!-- Le fonts -->
#   <style>
#    @font-face {
# ...

# %%
a = soup.find(attrs={"data-component-id":"4pbr6y23kkht"})
print(a.get('data-component-status'))
b = soup.find('span')
a
# Out:
# operational
# <div class="component-inner-container status-green" data-component-id="4pbr6y23kkht" data-component-status="operational" data-js-hook="component-group-opener">
# <span class="name">
# <span aria-expanded="false" aria-label="Toggle Azure - East US 2 (Virginia)" class="fa group-parent-indicator color-secondary font-small fa-plus-square-o" role="button" tabindex="0"></span>
# <span>
#          Azure - East US 2 (Virginia)
#        </span>
# </span>
# <span class="component-status tool" title="Groups take on the status of their most degraded child component or service. Click to see the status of the individual children.">
#
#     Operational
#
#   </span>
# <span class="tool icon-indicator fa fa-check" title="Operational"></span>
# </div>

# %%
soup.select('4pbr6y23kkht')
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 soup.select('4pbr6y23kkht')
#
# File c:\Users\divya\anaconda3\envs\py38_env\lib\site-packages\bs4\element.py:1992, in Tag.select(self, selector, namespaces, limit, **kwargs)
#    1987 if soupsieve is None:
#    1988     raise NotImplementedError(
#    1989         "Cannot execute CSS selectors because the soupsieve package is not installed."
#    1990     )
# -> 1992 results = soupsieve.select(selector, self, namespaces, limit, **kwargs)
#    1994 # We do this because it's more consistent and because
#    1995 # ResultSet.__getattr__ has a helpful error message.
#    1996 return ResultSet(None, results)
#
# File c:\Users\divya\anaconda3\envs\py38_env\lib\site-packages\soupsieve\__init__.py:147, in select(select, tag, namespaces, limit, flags, custom, **kwargs)
#     135 def select(
# ...

# %%
tag.name
# Out:
# 'div'

# %%
tag.attrs
# Out:
# {'class': ['layout-content', 'status', 'status-index', 'starter']}

# %%
a = (soup.find(string="Azure - East US 2 (Virginia)"))

# %%
soup.findall('class')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 soup.findall('class')
#
# TypeError: 'NoneType' object is not callable
